# %%
import pandas as pd

# %%
df = pd.read_csv('data/movies_metadata.csv')
# Out:
# /var/folders/vc/3bn3yckn0gsbzydv4tymntqh0000gn/T/ipykernel_78695/1446283634.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/movies_metadata.csv')

# %%
df.shape
# Out:
# (45466, 24)

# %%
df['original_title']
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45461                        رگ خواب
# 45462            Siglo ng Pagluluwal
# 45463                       Betrayal
# 45464            Satana likuyushchiy
# 45465                       Queerama
# Name: original_title, Length: 45466, dtype: object

# %%
selected = df[['original_title','imdb_id']]

# %%
dick = {}

# %%
for ind in selected.index:
    dick[selected['original_title'][ind]] = selected['imdb_id'][ind]

# %%
dick
# Out:
# {'Toy Story': 'tt0114709',
#  'Jumanji': 'tt0113497',
#  'Grumpier Old Men': 'tt0113228',
#  'Waiting to Exhale': 'tt0114885',
#  'Father of the Bride Part II': 'tt0113041',
#  'Heat': 'tt0093164',
#  'Sabrina': 'tt0047437',
#  'Tom and Huck': 'tt0112302',
#  'Sudden Death': 'tt0114576',
#  'GoldenEye': 'tt0113189',
#  'The American President': 'tt0112346',
#  'Dracula: Dead and Loving It': 'tt0112896',
#  'Balto': 'tt0112453',
#  'Nixon': 'tt0113987',
#  'Cutthroat Island': 'tt0112760',
#  'Casino': 'tt0112641',
#  'Sense and Sensibility': 'tt0254768',
#  'Four Rooms': 'tt0113101',
#  'Ace Ventura: When Nature Calls': 'tt0112281',
#  'Money Train': 'tt0113845',
#  'Get Shorty': 'tt0113161',
#  'Copycat': 'tt0112722',
#  'Assassins': 'tt0112401',
#  'Powder': 'tt0114168',
#  'Leaving Las Vegas': 'tt0113627',
#  'Othello': 'tt0082861',
#  'Now and Then': 'tt0114011',
#  'Persuasion': 'tt0066702',
#  'La Cité des Enfants Perdus': 'tt0112682',
#  '摇啊摇，摇到外婆桥': 'tt0115012',
# ...

# %%
dick['Casino']
# Out:
# 'tt0112641'

# %%
list = []

# %%
with open('file.txt', 'w') as file:
    for ind in selected.index:
        file.write(f"{selected['original_title'][ind]}\n")
        list.append(selected['original_title'][ind])

# %%
len(list)
# Out:
# 136398

# %%
with open('file.txt', 'r') as f:
    data = f.read()

type(data)
# Out:
# str

# %%
data.split('\n')
# Out:
# 45467
